# %% [markdown]
# # <font style="font-family:roboto;color:#455e6c"> Parametrising a Machine Learning Interatomic Potential </font>

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background:#e3f2fd; padding: 10px">
# <font style="font-family:roboto;color:#455e6c"> <b> DPG Tutorial: Automated Workflows and Machine Learning for Materials Science Simulations </b> </font> </br>
# <font style="font-family:roboto;color:#455e6c"> 8 March 2026 </font> </br> </br>
# Sriram Anand, Prabhath Chilakalapudi, Haitham Gaafer, Marvin Poul, Jan Janssen, Jörg Neugebauer </br>
# <i> Max Planck Institute for Sustainable Materials </i></br>
# </br>
# Sarath Menon, Minaam Qamar, Ralf Drautz </br>
# <i> Ruhr-Universität Bochum </i></br>
# </br>
# Tilmann Hickel </br>
# <i> Bundesanstalt für Materialforschung und -prüfung </i></br>
# </div>

# %% [markdown]
# ### References
#
# - [Lysogorskiy, Y. et al. Performant implementation of the atomic cluster expansion (PACE) and application to copper and silicon. npj Comput Mater 7, 97 (2021)](http://www.nature.com/articles/s41524-021-00559-9)

# %% [markdown]
# In this notebook we fit an [Atomic Cluster Expansion](https://doi.org/10.1103/PhysRevB.99.014104) interatomic potential using the [pacemaker](https://www.nature.com/articles/s41524-021-00559-9) software.

# %% [markdown]
# ## <font style="font-family:roboto;color:#455e6c"> Loading and Analyzing the dataset </font>

# %% [markdown]
# Recalling the workflow, we are in the first essential step of loading the training dataset

# %% [markdown]
# <div style="text-align: center;">
#     <img src="images/highlighted_workflow.png" alt="Fitting workflow" width="70%">
# </div>

# %% [markdown]
# As a first step, we load the dataset by specifying the `file_path'. This dataset has been generated for the CaMg system using the ASSYST approach discussed in the previous section [02_assyst.ipynb](02_assyst.ipynb).

# %% [markdown]
# ## <font style="font-family:roboto;color:#455e6c"> Split the dataset into training and test </font>

# %% [markdown]
# In a second step, we split the dataset into training and testing datasets.
#
# This is done by choosing the percentage used for the training dataset through the `training_frac` parameter, where `training_frac = 0.5` means we use 50% for training and 50% for testing.

# %% [markdown]
# The histogram of the total energies of all atomic structures in the dataset is plotted using the `PlotEnergyHistogram` node. Similarly, using the `PlotForcesHistogram` Node, we can plot the forces histogram

# %% [markdown]
# ## <font style="font-family:roboto;color:#455e6c"> Define and specify the configuration of the ACE potential </font>

# %% [markdown]
# Following the `PACEmaker` notation, we create a file similar to `input.yaml` (see the `PACEmaker` [documentation](https://pacemaker.readthedocs.io/en/latest/) for more details).
#
# ```
# fit:
#   fit_cycles: 1
#   loss: {L1_coeffs: 1e-08, L2_coeffs: 1e-08, kappa: 0.08, w0_rad: 0, w1_rad: 0, w2_rad: 0}
#   maxiter: 1000
#   optimizer: BFGS
#   trainable_parameters: ALL
#   weighting: {DE: 1.0, DElow: 1.0, DEup: 10.0, DF: 1.0, DFup: 50.0, energy: convex_hull,
#     nfit: 20000, reftype: all, seed: 42, type: EnergyBasedWeightingPolicy, wlow: 0.95}
# .
# .
# .
# potential:
#   bonds:
#     ALL:
#       dcut: 0.01
#       radbase: SBessel
#       radparameters: [5.25]
#       rcut: 6.0
#   elements: [Mg, Ca]
#   embeddings:
#     ALL:
#       fs_parameters: [1, 1, 1, 0.5]
#       ndensity: 2
#       npot: FinnisSinclairShiftedScaled
#   functions:
#     number_of_functions_per_element = 300
#     ALL:
#       lmax_by_orders: [15, 6, 2, 1]
#       nradmax_by_orders: [0, 6, 3, 1]

# %% [markdown]
# ### 1. Embeddings
# specify how the atomic energy $E_i$ depends on the ACE properties/densities $\varphi$. The most approximate approach, but the most efficient for potential fitting, is the linear expansion $E_i = \varphi$. Non-linear expansions, e.g. including the square root, provide more flexibility and accuracy of the final potential, but require significantly more computational resources for fitting.

# %% [markdown]
# Embeddings for `ALL` species:
# - non-linear `FinnisSinclairShiftedScaled`
# - 2 densities
# - fs_parameters': [1, 1, 1, 0.5]:
# $$E_i = 1.0 * \varphi(1)^1 + 1.0 * \varphi(2)^{0.5} = \varphi^{(1)} + \sqrt{\varphi^{(2)}} $$

# %% [markdown]
# ### 2. Radial functions

# %% [markdown]
# Radial functions are defined by orthogonal polynomals. Examples are:
# * (a) Exponentially-scaled Chebyshev polynomials (λ = 5.25)
# * (b) Power-law scaled Chebyshev polynomials (λ = 2.0)
# * (c) Simplified spherical Bessel functions

# %% [markdown]
# <div style="text-align: center;">
#   <img src="images/radial-functions-low.png" width="40%">
# </div>

# %% [markdown]
# Radial functions specification have to be provided for `ALL` species pairs (i.e. Al-Al, Al-Li, Li-Al, Li-Li):
#
# * based on the Simplified Bessel function
# * and cutoff, e.g. $r_c=6.0$

# %% [markdown]
# #### 3. B-basis functions

# %% [markdown]
# B-basis functions  specifications for `ALL` species type interactions, i.e. Al-Al block:
# * maximum order = 4, i.e. body-order 5 (1 central atom + 4 neighbour  densities)
# * nradmax_by_orders: 15, 3, 2, 1
# * lmax_by_orders: 0, 3, 2, 1

# %% [markdown]
# For simplicity, the main inputs that we will consider for the potential configurations are:
#
# - `number_of_functions_per_element`: specifies how many functions will be provided in the potential
# - `rcut`: specifies what the cutoff radius is

# %% [markdown]
# ## <font style="font-family:roboto;color:#455e6c"> Linear fitting </font>

# %% [markdown]
# Finally, we run our fit with the thus defined `potential_config` and then save the potential files inside a new folder.
#
# **Note:** Setting `verbose = True` will show all the details of building the design matrices.

# %% [markdown]
# ## <font style="font-family:roboto;color:#455e6c"> Workflow For Fitting and Validating the Potential </font>

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: #FFEDD1; padding: 10px">
# <p class="title"><b>Task</b></p>
#
# Create a workflow to fit a linear ACE potential, then perform a level 1 validation of the potential. Consider the following steps,
# 1. We need to get the `RunLinearFit` node and also `ParameterizePotentialConfig` node.
# 2. Use the fitted potential with `PredictEnergiesAndForces` node for both training and testing datasets.
# 3. Add fitting plotting nodes such as `PlotEnergyFittingCurve` or `PlotForcesFittingCurve` to see how accurate our fitted potentials are with respect to predicting `energies` and `forces`.
#
# **Hint**: You can find the relevant nodes to perform the fitting in `atomistic` -> `fitting` -> `ace` and for plotting in `atomistic` -> `fitting` -> `plot`
#
# Exercise: change the `number_of_functions_per_element` to a higher value (i.e., 50) and check the fitting curves. Did the fit get better or worse? why?
#
# **Note:** You can save the potential under a new name using the `filename` input in `save_potential` node.
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="images/validation_schematic.png" width="60%">
# </div>

# %%
from pyiron_workflow import Workflow
from pyironflow import PyironFlow
from pyironflow.gui import GUILayout

# %%
from pyiron_nodes.atomistic.fitting.dataset import ReadPickledDatasetAsDataframe, SplitTrainingAndTesting
from pyiron_nodes.atomistic.fitting.ace import ParameterizePotentialConfig, RunLinearFit, PredictEnergiesAndForces
from pyiron_nodes.atomistic.fitting.plot import PlotEnergyHistogram, PlotForcesHistogram, PlotEnergyFittingCurve, PlotForcesFittingCurve

# %%
def make_linearfit(
    workflow_name: str,
    file_path: str = "data/mgca.pckl.tgz",
    compression: str | None = None,
    training_frac: float | int = 0.5,
    number_of_functions_per_element: int | None = 10,
    rcut: float | int = 6.0,
):

    wf = Workflow(workflow_name)
    # Workflow connections
    wf.LoadDataset = ReadPickledDatasetAsDataframe(
        file_path=file_path, compression=compression
    )
    wf.PlotEnergyHistogram = PlotEnergyHistogram(
        wf.LoadDataset
    )
    wf.PlotForcesHistogram = PlotForcesHistogram(
        wf.LoadDataset
    )
    wf.SplitDataset = SplitTrainingAndTesting(
        data_df=wf.LoadDataset.outputs.df, training_frac=training_frac
    )
    wf.ParameterizePotentialConfig = ParameterizePotentialConfig(
        number_of_functions_per_element=number_of_functions_per_element, rcut=rcut
    )
    
    wf.RunLinearFit = RunLinearFit(
        potential_config=wf.ParameterizePotentialConfig,
        df_train=wf.SplitDataset.outputs.df_training,
        df_test=wf.SplitDataset.outputs.df_testing,
        verbose=False,
    )
    wf.PredictEnergiesAndForces = PredictEnergiesAndForces(
        potential_file_path=wf.RunLinearFit.outputs.potential_file_path,
        df_train=wf.SplitDataset.outputs.df_training,
        df_test=wf.SplitDataset.outputs.df_testing,
    )
    wf.PlotEnergyFittingCurve = PlotEnergyFittingCurve(wf.PredictEnergiesAndForces)
    wf.PlotForcesFittingCurve = PlotForcesFittingCurve(wf.PredictEnergiesAndForces)
    return wf

# %%
wf = make_linearfit("RunLinearFit_solution")

# %%
wf.pull()
# Out:
# /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyace/multispecies_basisextension.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ====================== TRAINING INFO ======================
# Training E RMSE: 160.54 meV/atom
# Training F RMSE: 105.63 meV/A
# ======================= TESTING INFO =======================
# Testing E RMSE: 158.99 meV/atom
# Testing F RMSE: 109.50 meV/A
# Potentials "Ca_Mg_linear_potential.yaml" and "Ca_Mg_linear_potential.yace" are saved in "/cmmc/u/hgaafer/pyiron/projects/Trial/dpg_tutorial_2026_pyiron_workflow/Linear_ace_potentials".
# Predicting Training Data:   0%|          | 0/19340 [00:00<?, ?it/s]
# Predicting Testing Data:   0%|          | 0/19341 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/nodes/composite.py:184, in Composite._run_while_children_or_signals_exist(self)
#     183 try:
# --> 184     receiving(firing)
#     185 except Exception as e:
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/channels.py:872, in AccumulatingInputSignal.__call__(self, other)
#     871 self.reset()
# --> 872 self.callback()
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/node.py:530, in Node.run(self, run_data_tree, run_parent_trees_too, fetch_input, check_readiness, raise_run_exceptions, rerun, emit_ran_signal, *args, **kwargs)
#     480 """
#     481 The master method for running in a variety of ways.
#     482 By default, whatever data is currently available in upstream nodes will be
#    (...)
#     527     overwritten by any subsequent graph-based data manipulation.
#     528 """
# --> 530 return super().run(
#     531     check_readiness=check_readiness,
#     532     raise_run_exceptions=raise_run_exceptions,
#     533     rerun=rerun,
#     534     before_run_kwargs={
#     535         "run_data_tree": run_data_tree,
#     536         "run_parent_trees_too": run_parent_trees_too,
#     537         "fetch_input": fetch_input,
#     538         "emit_ran_signal": emit_ran_signal,
#     539         "input_args": args,
#     540         "input_kwargs": kwargs,
#     541     },
#     542     run_finally_kwargs={
#     543         "emit_ran_signal": emit_ran_signal,
#     544         "raise_run_exceptions": raise_run_exceptions,
#     545     },
#     546 )
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/mixin/run.py:192, in Runnable.run(self, check_readiness, raise_run_exceptions, rerun, before_run_kwargs, run_kwargs, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs)
#     191 self.running = True
# --> 192 return self._run(
#     193     raise_run_exceptions=raise_run_exceptions,
#     194     run_exception_kwargs=run_exception_kwargs,
#     195     run_finally_kwargs=run_finally_kwargs,
#     196     finish_run_kwargs=finish_run_kwargs,
#     197     **run_kwargs,
#     198 )
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/node.py:630, in Node._run(self, raise_run_exceptions, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs)
#     629     self.parent.register_child_starting(self)
# --> 630 return super()._run(
#     631     raise_run_exceptions=raise_run_exceptions,
#     632     run_exception_kwargs=run_exception_kwargs,
#     633     run_finally_kwargs=run_finally_kwargs,
#     634     finish_run_kwargs=finish_run_kwargs,
#     635 )
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/mixin/run.py:268, in Runnable._run(self, raise_run_exceptions, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs, *args, **kwargs)
#     267 if raise_run_exceptions:
# --> 268     raise e
#     269 else:
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/mixin/run.py:263, in Runnable._run(self, raise_run_exceptions, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs, *args, **kwargs)
#     262 try:
# --> 263     run_output = self.on_run(*on_run_args, **on_run_kwargs)
#     264 except (Exception, KeyboardInterrupt) as e:
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/node.py:463, in Node.on_run(self, *args, **kwargs)
#     462 def on_run(self, *args, **kwargs) -> Any:
# --> 463     return self._on_run(*args, **kwargs)
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/nodes/function.py:318, in Function._on_run(self, **kwargs)
#     317 def _on_run(self, **kwargs):
# --> 318     return self.node_function(**kwargs)
#
# File /cmmc/u/hgaafer/pyiron/projects/Trial/dpg_tutorial_2026_pyiron_workflow/pyiron_nodes/atomistic/fitting/plot.py:125, in PlotEnergyFittingCurve(data_dict)
#     122     rmse_testing = _calc_rmse(
#     123         data_dict["reference_testing_epa"], data_dict["predicted_testing_epa"]
#     124     )
# --> 125     ax.scatter(
#     126         data_dict["reference_testing_epa"],
#     127         data_dict["predicted_testing_epa"],
#     128         color="black",
#     129         s=30,
#     130         marker="+",
#     131         label=f"Testing RMSE = {rmse_testing:.2f} (meV/atom)",
#     132     )
#     134 # Training set
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1523 if data is None:
# -> 1524     return func(
#    1525         ax,
#    1526         *map(cbook.sanitize_sequence, args),
#    1527         **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529 bound = new_sig.bind(ax, *args, **kwargs)
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4936, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4935 if x.size != y.size:
# -> 4936     raise ValueError("x and y must be the same size")
#    4938 if s is None:
#
# ValueError: x and y must be the same size
#
# The above exception was the direct cause of the following exception:
#
# FailedChildError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 wf.pull()
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/workflow.py:432, in Workflow.pull(self, run_parent_trees_too, **kwargs)
#     430 def pull(self, run_parent_trees_too=False, **kwargs):
#     431     """Workflows are a parent-most object, so this simply runs without pulling."""
# --> 432     return self.run(**kwargs)
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/workflow.py:384, in Workflow.run(self, check_readiness, rerun, *args, **kwargs)
#     378 if len(args) > 0:
#     379     raise NoArgsError(
#     380         f"{self.__class__} does not know how to process *args on run, but "
#     381         f"received {args}"
#     382     )
# --> 384 return super().run(
#     385     run_data_tree=False,
#     386     run_parent_trees_too=False,
#     387     fetch_input=False,
#     388     check_readiness=check_readiness,
#     389     rerun=rerun,
#     390     emit_ran_signal=False,
#     391     **kwargs,
#     392 )
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/node.py:530, in Node.run(self, run_data_tree, run_parent_trees_too, fetch_input, check_readiness, raise_run_exceptions, rerun, emit_ran_signal, *args, **kwargs)
#     468 def run(
#     469     self,
#     470     *args,
#    (...)
#     478     **kwargs,
#     479 ):
#     480     """
#     481     The master method for running in a variety of ways.
#     482     By default, whatever data is currently available in upstream nodes will be
#    (...)
#     527         overwritten by any subsequent graph-based data manipulation.
#     528     """
# --> 530     return super().run(
#     531         check_readiness=check_readiness,
#     532         raise_run_exceptions=raise_run_exceptions,
#     533         rerun=rerun,
#     534         before_run_kwargs={
#     535             "run_data_tree": run_data_tree,
#     536             "run_parent_trees_too": run_parent_trees_too,
#     537             "fetch_input": fetch_input,
#     538             "emit_ran_signal": emit_ran_signal,
#     539             "input_args": args,
#     540             "input_kwargs": kwargs,
#     541         },
#     542         run_finally_kwargs={
#     543             "emit_ran_signal": emit_ran_signal,
#     544             "raise_run_exceptions": raise_run_exceptions,
#     545         },
#     546     )
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/mixin/run.py:192, in Runnable.run(self, check_readiness, raise_run_exceptions, rerun, before_run_kwargs, run_kwargs, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs)
#     189     return result
#     191 self.running = True
# --> 192 return self._run(
#     193     raise_run_exceptions=raise_run_exceptions,
#     194     run_exception_kwargs=run_exception_kwargs,
#     195     run_finally_kwargs=run_finally_kwargs,
#     196     finish_run_kwargs=finish_run_kwargs,
#     197     **run_kwargs,
#     198 )
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/node.py:630, in Node._run(self, raise_run_exceptions, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs)
#     628 if self.parent is not None and self.parent.running:
#     629     self.parent.register_child_starting(self)
# --> 630 return super()._run(
#     631     raise_run_exceptions=raise_run_exceptions,
#     632     run_exception_kwargs=run_exception_kwargs,
#     633     run_finally_kwargs=run_finally_kwargs,
#     634     finish_run_kwargs=finish_run_kwargs,
#     635 )
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/mixin/run.py:268, in Runnable._run(self, raise_run_exceptions, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs, *args, **kwargs)
#     266 self._run_finally(**run_finally_kwargs)
#     267 if raise_run_exceptions:
# --> 268     raise e
#     269 else:
#     270     run_output = None
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/mixin/run.py:263, in Runnable._run(self, raise_run_exceptions, run_exception_kwargs, run_finally_kwargs, finish_run_kwargs, *args, **kwargs)
#     261 if self.executor is None:
#     262     try:
# --> 263         run_output = self.on_run(*on_run_args, **on_run_kwargs)
#     264     except (Exception, KeyboardInterrupt) as e:
#     265         self._run_exception(**run_exception_kwargs)
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/node.py:463, in Node.on_run(self, *args, **kwargs)
#     462 def on_run(self, *args, **kwargs) -> Any:
# --> 463     return self._on_run(*args, **kwargs)
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/nodes/composite.py:174, in Composite._on_run(self)
#     171     for node in self.starting_nodes:
#     172         node.run()
# --> 174 self._run_while_children_or_signals_exist()
#     176 return self
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyiron_workflow/nodes/composite.py:192, in Composite._run_while_children_or_signals_exist(self)
#     189         sleep(self._child_sleep_interval)
#     191 if len(errors) == 1:
# --> 192     raise FailedChildError(
#     193         f"{self.full_label} encountered error in child: {errors}"
#     194     ) from next(iter(errors.values()))
#     195 elif len(errors) > 1:
#     196     raise FailedChildError(
#     197         f"{self.full_label} encountered multiple errors in children: {errors}"
#     198     ) from None
#
# FailedChildError: /RunLinearFit_solution encountered error in child: {'/RunLinearFit_solution/PlotEnergyFittingCurve.accumulate_and_run': ValueError('x and y must be the same size')}

# %%
pf = PyironFlow([wf], nodes_path="pyiron_nodes")
pf.gui
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 workflow_path = "pyiron_core_data/workflows/"
# ----> 2 pf = PyironFlow([wf], nodes_path="pyiron_nodes", workflow_path = workflow_path)
#       3 pf.gui
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyironflow/gui.py:103, in PyironFlow.__init__(self, wf_list, hash_nodes, gui_layout, db, workflow_path, nodes_path, force_module_reload, debug, extra_workflow_paths, node_store_path)
#     101 self.wf_widgets: List[PyironFlowWidget] = []
#     102 for wf in wf_list:
# --> 103     w = PyironFlowWidget(
#     104         wf=wf,
#     105         gui_layout=gui_layout,
#     106         main_widget=self,
#     107         db=self.db,
#     108         workflow_path=workflow_path,
#     109         nodes_path=self.nodes_path,
#     110         flow_widget=self._shared_flow_widget,
#     111         extra_workflow_paths=self.extra_workflow_paths,
#     112         node_store_path=self.node_store_path,
#     113     )
#     114     w.graph.force_module_reload = self.force_module_reload
#     115     self.wf_widgets.append(w)
#
# File /cmmc/ptmp/pyironhb/mambaforge/envs/pyiron_mpie_cmti_2026-09-14/lib/python3.12/site-packages/pyironflow/flow_widget.py:332, in PyironFlowWidget.__init__(self, workflow_path, nodes_path, wf, gui_layout, main_widget, db, flow_widget, extra_workflow_paths, node_store_path)
#     330     self._cmd_load_workflow(wf)
#     331 else:
# --> 332     raise ValueError("wf must be a Workflow or Graph object")
#     334 # Sync _db onto the graph.  Graph.copy() only preserves _db when the
#     335 # source graph already had it; a plain user-created Workflow has _db=None
#     336 # even when the caller passes db= here.  Always inject it explicitly.
#     337 if hasattr(self, "graph"):
#
# ValueError: wf must be a Workflow or Graph object

# %% [markdown]
# <div style="text-align: center;">
#     <img src="images/fit_example.png" width="100%">
# </div>

# %% [raw]
# workflow_name = 'LinearAceDataset'
# file_path = 'data/mgca.pckl.tgz'
# compression = None
# training_frac = 0.5
# number_of_functions_per_element = 10
# rcut = 6.0

# %% [raw]
# wf = Workflow(workflow_name)
#
# # Workflow connections
# wf.load_dataset = ReadPickledDatasetAsDataframe(
#     file_path=file_path, compression=compression
# )
# wf.split_dataset = SplitTrainingAndTesting(
#     data_df=wf.load_dataset.outputs.df, training_frac=training_frac
# )
# wf.parameterize_potential = ParameterizePotentialConfig(
#     number_of_functions=number_of_functions_per_element, rcut=rcut
# )
# wf.run_linear_fit = RunLinearFit(
#     potential_config=wf.parameterize_potential,
#     df_train=wf.split_dataset.outputs.df_training,
#     df_test=wf.split_dataset.outputs.df_testing,
#     verbose=False,
# )
# wf.save_potential = SavePotential(basis=wf.run_linear_fit.outputs.basis)
# wf.predict_energies_forces = PredictEnergiesAndForces(
#     basis=wf.run_linear_fit.outputs.basis,
#     df_train=wf.split_dataset.outputs.df_training,
#     df_test=wf.split_dataset.outputs.df_testing,
# )
